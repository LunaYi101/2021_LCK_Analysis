# %%
from pandas import Series, DataFrame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 전체 플레이어 데이터에서 원딜 데이터 추출
player_data = pd.read_csv('LCK 2021 Spring - Player Stats - OraclesElixir.csv')
# 밑에 줄에서 ADC를 원하는 포지션으로 바꾸면 그 라인 데이터 역시 확인 가능합니다.
player_data = player_data[player_data['Pos']=='ADC']

# 편의를 위해 부수적인 기호 삭제
for col in player_data.columns:
    if isinstance(player_data[col].iloc[0], str):
        player_data[col] = player_data[col].map(lambda x: x.replace('%', ''))

# 전부 소수(float) 형으로 변경
for col in player_data.columns[3:]:
    player_data[col] = pd.to_numeric(player_data[col], downcast = 'float')
    
# K, D, A 평균으로 변경
for col in ['K', 'D', 'A']:
    player_data[col] = player_data[col]/player_data['GP']
        
player_data
# Out:
#       Player                 Team  Pos    GP    W%  CTR%         K         D  \
# 0       Bang       Afreeca Freecs  ADC  42.0  38.0  57.0  3.619048  2.261905
# 1        BAO                  DRX  ADC  47.0  45.0  47.0  3.808511  2.212766
# 2       Deft  Hanwha Life Esports  ADC  44.0  59.0  55.0  4.136364  2.409091
# 3    deokdam    Nongshim RedForce  ADC  42.0  43.0  45.0  4.357143  2.119048
# 4      Ghost              DWG KIA  ADC  43.0  77.0  42.0  4.744186  1.744186
# 5   Gumayusi                   T1  ADC  21.0  48.0  67.0  4.476191  1.904762
# 6       Hena         Fredit BRION  ADC  39.0  31.0  49.0  3.333333  2.051282
# 7     HyBriD           KT Rolster  ADC  35.0  40.0  54.0  4.057143  2.314286
# 8        Leo         Liiv SANDBOX  ADC   9.0  33.0  67.0  2.888889  2.666667
# 9       Noah           KT Rolster  ADC  10.0  40.0  50.0  3.300000  2.200000
# 10    Prince         Liiv SANDBOX  ADC  20.0  45.0  45.0  4.100000  2.250000
# 11     Route         Liiv SANDBOX  ADC  11.0  27.0  18.0  2.909091  2.363636
# 12     Ruler                Gen.G  ADC  44.0  66.0  50.0  3.590909  1.613636
# 13     Teddy                   T1  ADC  23.0  74.0  52.0  5.086957  1.956522
#
#            A  KDA  ...  XPD10  CSD10  CSPM     CS%P15    DPM       DMG%  \
# 0   3.571429  3.2  ...   33.0   -2.4   8.9  28.799999  411.0  22.100000
# 1   3.234043  3.2  ... -157.0   -4.6   9.3  29.799999  431.0  22.400000
# 2   4.954545  3.8  ...   22.0    4.6   8.9  27.799999  571.0  27.299999
# 3   3.357143  3.6  ...   90.0    5.4   9.4  31.000000  452.0  23.799999
# 4   5.232558  5.7  ...  -44.0   -7.0   8.9  28.500000  486.0  22.200001
# 5   3.619048  4.3  ...   65.0    4.5  10.3  34.099998  405.0  25.000000
# 6   3.794872  3.5  ...   -4.0   -0.1  10.1  34.400002  394.0  24.299999
# 7   3.171429  3.1  ...   69.0    1.1   9.6  29.900000  370.0  21.200001
# 8   3.444444  2.4  ...  -57.0   -5.6   9.0  29.000000  346.0  19.000000
# 9   3.000000  2.9  ... -150.0  -11.3   8.0  27.799999  410.0  25.500000
# 10  3.350000  3.3  ... -110.0   -2.0   9.6  29.600000  464.0  23.799999
# 11  3.909091  2.9  ...    4.0   -1.5   9.0  28.400000  341.0  19.100000
# 12  4.000000  4.7  ...   99.0    7.8  10.4  31.900000  455.0  25.200001
# 13  6.347826  5.8  ...  -28.0   -2.8   8.9  30.400000  577.0  27.100000
#
#      EGPM      GOLD%   WPM  WCPM
# 0   283.0  25.799999  0.76  0.39
# 1   291.0  26.100000  0.44  0.33
# 2   297.0  25.299999  0.68  0.38
# 3   305.0  28.000000  0.48  0.36
# 4   314.0  25.500000  0.79  0.38
# 5   327.0  28.799999  0.53  0.49
# 6   298.0  28.700001  0.63  0.49
# 7   298.0  26.100000  0.46  0.44
# 8   278.0  25.299999  0.62  0.34
# 9   271.0  25.299999  0.56  0.45
# 10  298.0  26.299999  0.49  0.45
# 11  268.0  24.900000  0.52  0.36
# 12  325.0  27.200001  0.77  0.55
# 13  324.0  26.600000  0.77  0.41
#
# [14 rows x 25 columns]

# %%
player_data['DMG%/KP'] = player_data['DMG%']
player_data['DMG%/KP'] /= player_data['KP']
player_data = player_data.sort_values('DMG%/KP', ascending=False)
player_data
# Out:
#       Player                 Team  Pos    GP    W%  CTR%         K         D  \
# 2       Deft  Hanwha Life Esports  ADC  44.0  59.0  55.0  4.136364  2.409091
# 12     Ruler                Gen.G  ADC  44.0  66.0  50.0  3.590909  1.613636
# 10    Prince         Liiv SANDBOX  ADC  20.0  45.0  45.0  4.100000  2.250000
# 13     Teddy                   T1  ADC  23.0  74.0  52.0  5.086957  1.956522
# 8        Leo         Liiv SANDBOX  ADC   9.0  33.0  67.0  2.888889  2.666667
# 0       Bang       Afreeca Freecs  ADC  42.0  38.0  57.0  3.619048  2.261905
# 9       Noah           KT Rolster  ADC  10.0  40.0  50.0  3.300000  2.200000
# 5   Gumayusi                   T1  ADC  21.0  48.0  67.0  4.476191  1.904762
# 1        BAO                  DRX  ADC  47.0  45.0  47.0  3.808511  2.212766
# 3    deokdam    Nongshim RedForce  ADC  42.0  43.0  45.0  4.357143  2.119048
# 7     HyBriD           KT Rolster  ADC  35.0  40.0  54.0  4.057143  2.314286
# 4      Ghost              DWG KIA  ADC  43.0  77.0  42.0  4.744186  1.744186
# 11     Route         Liiv SANDBOX  ADC  11.0  27.0  18.0  2.909091  2.363636
# 6       Hena         Fredit BRION  ADC  39.0  31.0  49.0  3.333333  2.051282
#
#            A  KDA  ...  CSD10  CSPM     CS%P15    DPM       DMG%   EGPM  \
# 2   4.954545  3.8  ...    4.6   8.9  27.799999  571.0  27.299999  297.0
# 12  4.000000  4.7  ...    7.8  10.4  31.900000  455.0  25.200001  325.0
# 10  3.350000  3.3  ...   -2.0   9.6  29.600000  464.0  23.799999  298.0
# 13  6.347826  5.8  ...   -2.8   8.9  30.400000  577.0  27.100000  324.0
# 8   3.444444  2.4  ...   -5.6   9.0  29.000000  346.0  19.000000  278.0
# 0   3.571429  3.2  ...   -2.4   8.9  28.799999  411.0  22.100000  283.0
# 9   3.000000  2.9  ...  -11.3   8.0  27.799999  410.0  25.500000  271.0
# 5   3.619048  4.3  ...    4.5  10.3  34.099998  405.0  25.000000  327.0
# 1   3.234043  3.2  ...   -4.6   9.3  29.799999  431.0  22.400000  291.0
# 3   3.357143  3.6  ...    5.4   9.4  31.000000  452.0  23.799999  305.0
# 7   3.171429  3.1  ...    1.1   9.6  29.900000  370.0  21.200001  298.0
# 4   5.232558  5.7  ...   -7.0   8.9  28.500000  486.0  22.200001  314.0
# 11  3.909091  2.9  ...   -1.5   9.0  28.400000  341.0  19.100000  268.0
# 6   3.794872  3.5  ...   -0.1  10.1  34.400002  394.0  24.299999  298.0
#
#         GOLD%   WPM  WCPM   DMG%/KP
# 2   25.299999  0.68  0.38  0.419355
# 12  27.200001  0.77  0.55  0.412439
# 10  26.299999  0.49  0.45  0.388254
# 13  26.600000  0.77  0.41  0.384397
# 8   25.299999  0.62  0.34  0.376984
# 0   25.799999  0.76  0.39  0.372681
# 9   25.299999  0.56  0.45  0.356145
# 5   28.799999  0.53  0.49  0.351617
# 1   26.100000  0.44  0.33  0.350548
# 3   28.000000  0.48  0.36  0.349486
# 7   26.100000  0.46  0.44  0.345277
# 4   25.500000  0.79  0.38  0.334842
# 11  24.900000  0.52  0.36  0.315702
# 6   28.700001  0.63  0.49  0.315584
#
# [14 rows x 26 columns]

# %%
spring_rank = ['DWG KIA', 'Gen.G', 'Hanwha Life Esports', 'T1', 'DRX', 'Nongshim RedForce', 'KT Rolster', 'Afreeca Freecs', 'Liiv SANDBOX', 'Fredit BRION']

player_data.Team = pd.Categorical(player_data.Team, categories=spring_rank, ordered = True)
player_data.sort_values('Team', inplace=True)

spring_rank_list = [spring_rank.index(x)+1 for x in player_data.Team]
player_data['Spring_Rank'] = spring_rank_list

player_data
# Out:
#       Player                 Team  Pos    GP    W%  CTR%         K         D  \
# 4      Ghost              DWG KIA  ADC  43.0  77.0  42.0  4.744186  1.744186
# 12     Ruler                Gen.G  ADC  44.0  66.0  50.0  3.590909  1.613636
# 2       Deft  Hanwha Life Esports  ADC  44.0  59.0  55.0  4.136364  2.409091
# 13     Teddy                   T1  ADC  23.0  74.0  52.0  5.086957  1.956522
# 5   Gumayusi                   T1  ADC  21.0  48.0  67.0  4.476191  1.904762
# 1        BAO                  DRX  ADC  47.0  45.0  47.0  3.808511  2.212766
# 3    deokdam    Nongshim RedForce  ADC  42.0  43.0  45.0  4.357143  2.119048
# 9       Noah           KT Rolster  ADC  10.0  40.0  50.0  3.300000  2.200000
# 7     HyBriD           KT Rolster  ADC  35.0  40.0  54.0  4.057143  2.314286
# 0       Bang       Afreeca Freecs  ADC  42.0  38.0  57.0  3.619048  2.261905
# 10    Prince         Liiv SANDBOX  ADC  20.0  45.0  45.0  4.100000  2.250000
# 8        Leo         Liiv SANDBOX  ADC   9.0  33.0  67.0  2.888889  2.666667
# 11     Route         Liiv SANDBOX  ADC  11.0  27.0  18.0  2.909091  2.363636
# 6       Hena         Fredit BRION  ADC  39.0  31.0  49.0  3.333333  2.051282
#
#            A  KDA  ...  CSPM     CS%P15    DPM       DMG%   EGPM      GOLD%  \
# 4   5.232558  5.7  ...   8.9  28.500000  486.0  22.200001  314.0  25.500000
# 12  4.000000  4.7  ...  10.4  31.900000  455.0  25.200001  325.0  27.200001
# 2   4.954545  3.8  ...   8.9  27.799999  571.0  27.299999  297.0  25.299999
# 13  6.347826  5.8  ...   8.9  30.400000  577.0  27.100000  324.0  26.600000
# 5   3.619048  4.3  ...  10.3  34.099998  405.0  25.000000  327.0  28.799999
# 1   3.234043  3.2  ...   9.3  29.799999  431.0  22.400000  291.0  26.100000
# 3   3.357143  3.6  ...   9.4  31.000000  452.0  23.799999  305.0  28.000000
# 9   3.000000  2.9  ...   8.0  27.799999  410.0  25.500000  271.0  25.299999
# 7   3.171429  3.1  ...   9.6  29.900000  370.0  21.200001  298.0  26.100000
# 0   3.571429  3.2  ...   8.9  28.799999  411.0  22.100000  283.0  25.799999
# 10  3.350000  3.3  ...   9.6  29.600000  464.0  23.799999  298.0  26.299999
# 8   3.444444  2.4  ...   9.0  29.000000  346.0  19.000000  278.0  25.299999
# 11  3.909091  2.9  ...   9.0  28.400000  341.0  19.100000  268.0  24.900000
# 6   3.794872  3.5  ...  10.1  34.400002  394.0  24.299999  298.0  28.700001
#
#      WPM  WCPM   DMG%/KP  Spring_Rank
# 4   0.79  0.38  0.334842            1
# 12  0.77  0.55  0.412439            2
# 2   0.68  0.38  0.419355            3
# 13  0.77  0.41  0.384397            4
# 5   0.53  0.49  0.351617            4
# 1   0.44  0.33  0.350548            5
# 3   0.48  0.36  0.349486            6
# 9   0.56  0.45  0.356145            7
# 7   0.46  0.44  0.345277            7
# 0   0.76  0.39  0.372681            8
# 10  0.49  0.45  0.388254            9
# 8   0.62  0.34  0.376984            9
# 11  0.52  0.36  0.315702            9
# 6   0.63  0.49  0.315584           10
#
# [14 rows x 27 columns]

# %%
# 스프링 시즌 등수와 상관 계수가 0.8이상인 지표 (3점)
rank_1_columns = player_data.corr()[player_data.corr()['Spring_Rank']<=-0.8].index
rank_1_columns = [item for item in rank_1_columns]

# 스프링 시즌 등수와 상관 계수가 0.6이상인 지표 (2점)
rank_2_columns = player_data.corr()[player_data.corr()['Spring_Rank']<=-0.6].index
rank_2_columns = [item for item in rank_2_columns if item not in rank_1_columns]

# 스프링 시즌 등수와 상관 계수가 0.4이상인 지표 (1점)
rank_3_columns = player_data.corr()[player_data.corr()['Spring_Rank']<=-0.4].index
rank_3_columns = [item for item in rank_3_columns if item not in rank_2_columns]
rank_3_columns = [item for item in rank_3_columns if item not in rank_1_columns]

# 선수별 점수 저장 DataFrame 만들기
tmp_list = np.array([0] * player_data['Player'].count())
ADC_score = DataFrame(data=tmp_list, index = player_data.Player, columns = ['Score'])

print(rank_1_columns)
print(rank_2_columns)
print(rank_3_columns)
# Out:
# ['W%']
# ['K', 'KDA', 'DPM', 'EGPM']
# ['GP', 'A', 'FB%', 'GD10', 'DMG%', 'WPM']

# %%
copied_player_data = player_data
for column in rank_1_columns:
    copied_player_data.sort_values(column, inplace=True) # 해당 지표로 정렬 역순
    copied_player_data['Rank'] = np.arange(copied_player_data['Player'].count()) # 순위 매기기
    ADC_score = ADC_score.add(DataFrame(data=Series(list(copied_player_data['Rank']*3), index=list(copied_player_data['Player'])),index = player_data.Player, columns = ['Score']))

# %%
for column in rank_2_columns:
    copied_player_data.sort_values(column, inplace=True) # 해당 지표로 정렬 역순
    copied_player_data['Rank'] = np.arange(copied_player_data['Player'].count()) # 순위 매기기
    ADC_score = ADC_score.add(DataFrame(data=Series(list(copied_player_data['Rank']*2), index=list(copied_player_data['Player'])),index = player_data.Player, columns = ['Score']))

# %%
for column in rank_3_columns:
    copied_player_data.sort_values(column, inplace=True) # 해당 지표로 정렬 역순
    copied_player_data['Rank'] = np.arange(copied_player_data['Player'].count()) # 순위 매기기
    ADC_score = ADC_score.add(DataFrame(data=Series(list(copied_player_data['Rank']), index=list(copied_player_data['Player'])),index = player_data.Player, columns = ['Score']))

# %%
ADC_score.sort_values('Score', ascending=False)
# Out:
#           Score
# Player
# Teddy       202
# Ghost       184
# Ruler       166
# Deft        157
# Gumayusi    152
# deokdam     127
# Prince      108
# BAO          92
# Bang         86
# Hena         84
# HyBriD       76
# Noah         64
# Route        25
# Leo          24

# %%
pd.set_option('display.max_rows', 500)
